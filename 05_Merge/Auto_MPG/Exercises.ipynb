# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %% [markdown]
#    ### Step 3. Assign each to a variable called cars1 and cars2

# %%
dir = 'C:\\Users\\Lenovo\\PycharmProjects\\pandas_exercises\\05_Merge\\Auto_MPG\\'
cars1 = pd.read_csv(dir + 'cars1.csv')
cars2 = pd.read_csv(dir + 'cars2.csv')
cars1.head()
cars2.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mpg</th>
#       <th>cylinders</th>
#       <th>displacement</th>
#       <th>horsepower</th>
#       <th>weight</th>
#       <th>acceleration</th>
#       <th>model</th>
#       <th>origin</th>
#       <th>car</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>33.0</td>
#       <td>4</td>
#       <td>91</td>
#       <td>53</td>
#       <td>1795</td>
#       <td>17.4</td>
#       <td>76</td>
#       <td>3</td>
#       <td>honda civic</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20.0</td>
#       <td>6</td>
#       <td>225</td>
#       <td>100</td>
# ...

# %% [markdown]
# ### Step 4. Ops it seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1 = cars1.drop(['Unnamed: 9', 'Unnamed: 10',
            'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'], axis=1)

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print('cars1: ', cars1.shape[0],'; cars2: ', cars2.shape[0])
# Out:
# cars1:  198 ; cars2:  200

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars = pd.concat([cars1, cars2])
cars.index = np.arange(0, cars.shape[0])

# %% [markdown]
# ### Step 7. Ops there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
owners = pd.Series(np.random.randint(15000, 73000, size=(398,)), name='owners')
owners
# Out:
# 0      63313
# 1      23768
# 2      15320
# 3      43343
# 4      37448
# 5      56944
# 6      62112
# 7      33938
# 8      15306
# 9      65403
# 10     35946
# 11     29633
# 12     71637
# 13     47534
# 14     30406
# 15     53453
# 16     42332
# 17     45504
# 18     42597
# 19     38941
# 20     32390
# 21     32667
# 22     56008
# 23     20601
# 24     20197
# 25     16084
# 26     50060
# 27     18726
# 28     60929
# 29     26904
#        ...
# 368    28105
# 369    41688
# 370    38171
# 371    47017
# 372    17871
# 373    60999
# 374    21410
# 375    60281
# 376    70067
# 377    30300
# 378    68615
# 379    27957
# 380    34027
# 381    52455
# 382    56978
# 383    37119
# 384    47389
# 385    22052
# 386    30502
# 387    23039
# 388    44391
# 389    32823
# 390    38779
# 391    65242
# 392    53177
# 393    60782
# 394    54594
# 395    64510
# 396    56709
# 397    69595
# Name: owners, Length: 398, dtype: int32

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
pd.concat([cars, owners], axis=1)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mpg</th>
#       <th>cylinders</th>
#       <th>displacement</th>
#       <th>horsepower</th>
#       <th>weight</th>
#       <th>acceleration</th>
#       <th>model</th>
#       <th>origin</th>
#       <th>car</th>
#       <th>owners</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>18.0</td>
#       <td>8</td>
#       <td>307</td>
#       <td>130</td>
#       <td>3504</td>
#       <td>12.0</td>
#       <td>70</td>
#       <td>1</td>
#       <td>chevrolet chevelle malibu</td>
#       <td>63313</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>15.0</td>
# ...
