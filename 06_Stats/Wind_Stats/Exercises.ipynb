# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/guipsamora/pandas_exercises/blob/master/Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
httml = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data'
data = pd.read_csv(httml, sep='\s+', parse_dates=[[0, 1, 2]])

#data.set_index('Yr_Mo_Dy', inplace=True)
data.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yr_Mo_Dy</th>
#       <th>RPT</th>
#       <th>VAL</th>
#       <th>ROS</th>
#       <th>KIL</th>
#       <th>SHA</th>
#       <th>BIR</th>
#       <th>DUB</th>
#       <th>CLA</th>
#       <th>MUL</th>
#       <th>CLO</th>
#       <th>BEL</th>
#       <th>MAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2061-01-01</td>
#       <td>15.04</td>
#       <td>14.96</td>
#       <td>13.17</td>
#       <td>9.29</td>
#       <td>NaN</td>
#       <td>9.87</td>
#       <td>13.67</td>
#       <td>10.25</td>
#       <td>10.83</td>
#       <td>12.58</td>
#       <td>18.50</td>
# ...

# %%
#pd.to_datetime(data.Yr_Mo_Dy).dtypes
#data.Yr_Mo_Dy.dtypes
#data.Yr_Mo_Dy = data.Yr_Mo_Dy - pd.to_timedelta(100, 'Y')
#data.Yr_Mo_Dy = data.Yr_Mo_Dy.apply(lambda x: x.date())

# %%
#data.set_index(data.Yr_Mo_Dy, drop=True, inplace=True)

# %%
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yr_Mo_Dy</th>
#       <th>RPT</th>
#       <th>VAL</th>
#       <th>ROS</th>
#       <th>KIL</th>
#       <th>SHA</th>
#       <th>BIR</th>
#       <th>DUB</th>
#       <th>CLA</th>
#       <th>MUL</th>
#       <th>CLO</th>
#       <th>BEL</th>
#       <th>MAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2061-01-01</td>
#       <td>15.04</td>
#       <td>14.96</td>
#       <td>13.17</td>
#       <td>9.29</td>
#       <td>NaN</td>
#       <td>9.87</td>
#       <td>13.67</td>
#       <td>10.25</td>
#       <td>10.83</td>
#       <td>12.58</td>
#       <td>18.50</td>
# ...

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
def func(x):
    year = x.year - 100 if x.year > 1989 else x.year
    return dt.datetime(year, x.month, x.day)

data['Yr_Mo_Dy'] = data['Yr_Mo_Dy'].apply(func)

data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Yr_Mo_Dy</th>
#       <th>RPT</th>
#       <th>VAL</th>
#       <th>ROS</th>
#       <th>KIL</th>
#       <th>SHA</th>
#       <th>BIR</th>
#       <th>DUB</th>
#       <th>CLA</th>
#       <th>MUL</th>
#       <th>CLO</th>
#       <th>BEL</th>
#       <th>MAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1961-01-01</td>
#       <td>15.04</td>
#       <td>14.96</td>
#       <td>13.17</td>
#       <td>9.29</td>
#       <td>NaN</td>
#       <td>9.87</td>
#       <td>13.67</td>
#       <td>10.25</td>
#       <td>10.83</td>
#       <td>12.58</td>
#       <td>18.50</td>
# ...

# %%
data['year'] = data['Yr_Mo_Dy'].apply(lambda x: x.year)
data.groupby('year').mean()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>RPT</th>
#       <th>VAL</th>
#       <th>ROS</th>
#       <th>KIL</th>
#       <th>SHA</th>
#       <th>BIR</th>
#       <th>DUB</th>
#       <th>CLA</th>
#       <th>MUL</th>
#       <th>CLO</th>
#       <th>BEL</th>
#       <th>MAL</th>
#     </tr>
#     <tr>
#       <th>year</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1961</th>
#       <td>12.299583</td>
# ...

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data['Yr_Mo_Dy'] = pd.to_datetime(data['Yr_Mo_Dy'])
data.set_index('Yr_Mo_Dy', inplace=True)

# %%
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>RPT</th>
#       <th>VAL</th>
#       <th>ROS</th>
#       <th>KIL</th>
#       <th>SHA</th>
#       <th>BIR</th>
#       <th>DUB</th>
#       <th>CLA</th>
#       <th>MUL</th>
#       <th>CLO</th>
#       <th>BEL</th>
#       <th>MAL</th>
#       <th>year</th>
#     </tr>
#     <tr>
#       <th>Yr_Mo_Dy</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isnull().sum()
# Out:
# RPT     6
# VAL     3
# ROS     2
# KIL     5
# SHA     2
# BIR     0
# DUB     3
# CLA     2
# MUL     3
# CLO     1
# BEL     0
# MAL     4
# year    0
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.count().sum()
# Out:
# 85431

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data.sum().sum() / data.count().sum() == data.mean().mean()
# Out:
# False

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats = pd.DataFrame()
loc_stats['min'] = data.min()
loc_stats['max'] = data.max()
loc_stats['mean'] = data.mean()
loc_stats['std'] = data.std()
loc_stats = loc_stats.transpose()
loc_stats
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>RPT</th>
#       <th>VAL</th>
#       <th>ROS</th>
#       <th>KIL</th>
#       <th>SHA</th>
#       <th>BIR</th>
#       <th>DUB</th>
#       <th>CLA</th>
#       <th>MUL</th>
#       <th>CLO</th>
#       <th>BEL</th>
#       <th>MAL</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>min</th>
#       <td>0.670000</td>
#       <td>0.210000</td>
#       <td>1.500000</td>
#       <td>0.000000</td>
#       <td>0.130000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.040000</td>
#       <td>0.130000</td>
# ...

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats = pd.DataFrame()
day_stats['min'] = data.apply(np.min, axis=1)
day_stats['max'] = data.apply(np.max, axis=1)
day_stats['mean'] = data.apply(np.mean, axis=1)
day_stats['std'] = data.apply(np.std, axis=1)
day_stats.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>std</th>
#     </tr>
#     <tr>
#       <th>Yr_Mo_Dy</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1961-01-01</th>
#       <td>9.29</td>
#       <td>1961.0</td>
#       <td>175.350000</td>
#       <td>538.399838</td>
#     </tr>
#     <tr>
#       <th>1961-01-02</th>
#       <td>6.50</td>
#       <td>1961.0</td>
#       <td>173.808333</td>
#       <td>538.866426</td>
#     </tr>
#     <tr>
#       <th>1961-01-03</th>
#       <td>6.17</td>
# ...

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
data[data.index.month == 1].mean()
# Out:
# RPT       14.847325
# VAL       12.914560
# ROS       13.299624
# KIL        7.199498
# SHA       11.667734
# BIR        8.054839
# DUB       11.819355
# CLA        9.512047
# MUL        9.543208
# CLO       10.053566
# BEL       14.550520
# MAL       18.028763
# year    1969.500000
# dtype: float64

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
data.resample('Y').mean()
data[(data.index.month == 1) & (data.index.day == 1)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>RPT</th>
#       <th>VAL</th>
#       <th>ROS</th>
#       <th>KIL</th>
#       <th>SHA</th>
#       <th>BIR</th>
#       <th>DUB</th>
#       <th>CLA</th>
#       <th>MUL</th>
#       <th>CLO</th>
#       <th>BEL</th>
#       <th>MAL</th>
#       <th>year</th>
#     </tr>
#     <tr>
#       <th>Yr_Mo_Dy</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
data[data.index.day == 1].head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>RPT</th>
#       <th>VAL</th>
#       <th>ROS</th>
#       <th>KIL</th>
#       <th>SHA</th>
#       <th>BIR</th>
#       <th>DUB</th>
#       <th>CLA</th>
#       <th>MUL</th>
#       <th>CLO</th>
#       <th>BEL</th>
#       <th>MAL</th>
#       <th>year</th>
#     </tr>
#     <tr>
#       <th>Yr_Mo_Dy</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
data.resample('W').mean().head()
data[::7].head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>RPT</th>
#       <th>VAL</th>
#       <th>ROS</th>
#       <th>KIL</th>
#       <th>SHA</th>
#       <th>BIR</th>
#       <th>DUB</th>
#       <th>CLA</th>
#       <th>MUL</th>
#       <th>CLO</th>
#       <th>BEL</th>
#       <th>MAL</th>
#       <th>year</th>
#     </tr>
#     <tr>
#       <th>Yr_Mo_Dy</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ### Step 15. Calculate the mean windspeed for each month in the dataset.
# #### Treat January 1961 and January 1962 as *different* months.
# #### (hint: first find a  way to create an identifier unique for each month.)

# %%
data2 = data.copy()
data2['Year'] = data2.index.year
data2['Month'] = data2.index.month
data2.set_index(['Year', 'Month'], inplace=True)

data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>RPT</th>
#       <th>VAL</th>
#       <th>ROS</th>
#       <th>KIL</th>
#       <th>SHA</th>
#       <th>BIR</th>
#       <th>DUB</th>
#       <th>CLA</th>
#       <th>MUL</th>
#       <th>CLO</th>
#       <th>BEL</th>
#       <th>MAL</th>
#       <th>year</th>
#     </tr>
#     <tr>
#       <th>Yr_Mo_Dy</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
data2 = data.copy()
del data2['year']
data2['Year'] = data2.index.year
data2['Month'] = data2.index.month
data2.groupby(['Year', 'Month']).mean()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>RPT</th>
#       <th>VAL</th>
#       <th>ROS</th>
#       <th>KIL</th>
#       <th>SHA</th>
#       <th>BIR</th>
#       <th>DUB</th>
#       <th>CLA</th>
#       <th>MUL</th>
#       <th>CLO</th>
#       <th>BEL</th>
#       <th>MAL</th>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <th>Month</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ### Step 16. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
data['Week'] = data.index.week
# data.drop('year', axis=1, inplace=True)
data[1: 52 * 7 + 1:].groupby('Week').agg(['min', 'max', 'mean', 'std'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="4" halign="left">RPT</th>
#       <th colspan="4" halign="left">VAL</th>
#       <th colspan="2" halign="left">ROS</th>
#       <th>...</th>
#       <th colspan="2" halign="left">CLO</th>
#       <th colspan="4" halign="left">BEL</th>
#       <th colspan="4" halign="left">MAL</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>max</th>
# ...

# %%
data[1:52*7 + 1:].resample('W').agg(['min', 'max'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">RPT</th>
#       <th colspan="2" halign="left">VAL</th>
#       <th colspan="2" halign="left">ROS</th>
#       <th colspan="2" halign="left">KIL</th>
#       <th colspan="2" halign="left">SHA</th>
#       <th>...</th>
#       <th colspan="2" halign="left">CLA</th>
#       <th colspan="2" halign="left">MUL</th>
#       <th colspan="2" halign="left">CLO</th>
#       <th colspan="2" halign="left">BEL</th>
#       <th colspan="2" halign="left">MAL</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>min</th>
#       <th>max</th>
# ...
