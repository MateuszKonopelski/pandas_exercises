# %% [markdown]
# # Investor - Flow of Funds - US

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/rgrp for sharing the dataset.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
httml = 'https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv'
data = pd.read_csv(httml)
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Total Equity</th>
#       <th>Domestic Equity</th>
#       <th>World Equity</th>
#       <th>Hybrid</th>
#       <th>Total Bond</th>
#       <th>Taxable Bond</th>
#       <th>Municipal Bond</th>
#       <th>Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2012-12-05</td>
#       <td>-7426</td>
#       <td>-6060</td>
#       <td>-1367</td>
#       <td>-74</td>
#       <td>5317</td>
#       <td>4210</td>
#       <td>1107</td>
#       <td>-2183</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2012-12-12</td>
#       <td>-8783</td>
# ...

# %% [markdown]
# ### Step 4.  What is the frequency of the dataset?

# %%
data.Date = pd.to_datetime(data.Date)

# %%
(data.Date[1] - data.Date[0]).days
# Out:
# 7

# %% [markdown]
# ### Step 5. Set the column Date as the index.

# %%
data.set_index('Date', inplace=True)

# %% [markdown]
# ### Step 6. What is the type of the index?

# %%
data.index.dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### Step 7. Set the index to a DatetimeIndex type

# %% [markdown]
# ### Step 8.  Change the frequency to monthly, sum the values and assign it to monthly.

# %%
monthly = data.resample('M').sum()
monthly.head(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Total Equity</th>
#       <th>Domestic Equity</th>
#       <th>World Equity</th>
#       <th>Hybrid</th>
#       <th>Total Bond</th>
#       <th>Taxable Bond</th>
#       <th>Municipal Bond</th>
#       <th>Total</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2012-12-31</th>
#       <td>-26156</td>
#       <td>-23126</td>
#       <td>-3031</td>
#       <td>526</td>
#       <td>9848</td>
#       <td>12613</td>
# ...

# %% [markdown]
# ### Step 9. You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.

# %%
monthly =  monthly.query('Total != 0')

# %% [markdown]
# ### Step 10. Good, now we have the monthly data. Now change the frequency to year.

# %%
yearly = monthly.resample('AS-JAN').sum()
yearly
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Total Equity</th>
#       <th>Domestic Equity</th>
#       <th>World Equity</th>
#       <th>Hybrid</th>
#       <th>Total Bond</th>
#       <th>Taxable Bond</th>
#       <th>Municipal Bond</th>
#       <th>Total</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2012-01-01</th>
#       <td>-26156</td>
#       <td>-23126</td>
#       <td>-3031</td>
#       <td>526</td>
#       <td>9848</td>
#       <td>12613</td>
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.
